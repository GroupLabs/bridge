# %%
import pandas as pd

# Replace 'your_file.jsonl' with the path to your JSONL file
file_path = 'events.jsonl'

# # Reading the JSONL file directly into a DataFrame
df = pd.read_json(file_path, lines=True)

# %%
df['action'].value_counts()
# Out:
# action
# move       13163
# scroll       140
# click         44
# press         27
# release       27
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['time_stamp', 'action', 'x', 'y', 'button', 'pressed', 'name', 'dx',
#        'dy'],
#       dtype='object')

# %%
df.loc[df["action"] != 'move']
# Out:
#           time_stamp   action            x           y button  pressed name  \
# 430    150161.533522    click  1319.113281   65.066406   left      1.0  NaN
# 431    150161.597598    click  1319.113281   65.066406   left      0.0  NaN
# 432    150162.266222    press          NaN         NaN    NaN      NaN    w
# 433    150162.317228  release          NaN         NaN    NaN      NaN    w
# 434    150162.334653    press          NaN         NaN    NaN      NaN    i
# ...              ...      ...          ...         ...    ...      ...  ...
# 12412  150191.012791   scroll   651.273438  591.792969    NaN      NaN  NaN
# 13207  150192.052410    click  1173.023438   10.808594   left      1.0  NaN
# 13208  150192.143413    click  1173.023438   10.808594   left      0.0  NaN
# 13399  150193.390943    click  1178.687500   50.457031   left      1.0  NaN
# 13400  150193.467402    click  1178.687500   50.457031   left      0.0  NaN
#
#         dx   dy
# 430    NaN  NaN
# 431    NaN  NaN
# 432    NaN  NaN
# 433    NaN  NaN
# 434    NaN  NaN
# ...    ...  ...
# 12412  0.0 -1.0
# 13207  NaN  NaN
# 13208  NaN  NaN
# 13399  NaN  NaN
# 13400  NaN  NaN
#
# [238 rows x 9 columns]
