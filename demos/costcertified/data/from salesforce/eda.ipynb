# %%
import pandas as pd

# Replace 'your_file.jsonl' with the path to your JSONL file
file_path = 'Activities by Salesperson.csv'

# # Reading the JSONL file directly into a DataFrame
df = pd.read_csv(file_path)

# %%
df
# Out:
#                                          Subject Priority  Task  \
# 0                 Demo Platform Widgets (Sample)   Normal     1
# 1                            Discussion (Sample)   Normal     1
# 2                               Sync Up (Sample)   Normal     1
# 3                                Review (Sample)   Normal     1
# 4                 Call Jon for feedback (sample)   Normal     1
# 5               Review Pricing Proposal (sample)   Normal     1
# 6                Send latest whitepaper (Sample)   Normal     1
# 7   Discuss latest marketing whitepaper (Sample)   Normal     1
# 8                 Follow up with Howard (Sample)   Normal     1
# 9       Follow Up with Howard on timing (Sample)   Normal     1
# 10                              Debrief (Sample)   Normal     1
# 11                     Planning for RFP (Sample)   Normal     1
#
#          Company / Account                 Contact                    Lead  \
# 0      Lee Enterprise, Inc                     NaN     Amy Jordan (Sample)
# 1     Green Dot Publishing                     NaN  David Adelson (Sample)
# 2            MedLife, Inc.                     NaN    Sarah Loehr (Sample)
# 3   Universal Technologies                     NaN     Andy Smith (Sample)
# 4    Global Media (Sample)       Jon Amos (Sample)                     NaN
# 5    Global Media (Sample)   Carole White (Sample)                     NaN
# 6    Global Media (Sample)    Geoff Minor (Sample)                     NaN
# 7            Acme (Sample)  Leanne Tomlin (Sample)                     NaN
# 8            Acme (Sample)   Howard Jones (Sample)                     NaN
# 9            Acme (Sample)   Howard Jones (Sample)                     NaN
# 10           Acme (Sample)                     NaN                     NaN
# 11           Acme (Sample)                     NaN                     NaN
#
#                       Opportunity     Assigned
# 0                             NaN  Noel Thomas
# 1                             NaN  Noel Thomas
# 2                             NaN  Noel Thomas
# 3                             NaN  Noel Thomas
# 4                             NaN  Noel Thomas
# 5                             NaN  Noel Thomas
# 6                             NaN  Noel Thomas
# 7                             NaN  Noel Thomas
# 8                             NaN  Noel Thomas
# 9   Acme - 1,200 Widgets (Sample)  Noel Thomas
# 10  Acme - 1,200 Widgets (Sample)  Noel Thomas
# 11  Acme - 1,200 Widgets (Sample)  Noel Thomas
