# %%
from PIL import Image
from surya.ocr import run_ocr
from surya.model.detection import segformer
from surya.model.recognition.model import load_model
from surya.model.recognition.processor import load_processor

image = Image.open("report.png")
langs = ["en"] # Replace with your languages
det_processor, det_model = segformer.load_processor(), segformer.load_model()
rec_model, rec_processor = load_model(), load_processor()

predictions = run_ocr([image], [langs], det_model, det_processor, rec_model, rec_processor)
# Out:
# /Users/noelthomas/Documents/GitHub/bridge/.venv/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loaded detection model vikp/surya_det2 on device cpu with dtype torch.float32
# Loaded recognition model vikp/surya_rec on device mps with dtype torch.float16
# Detecting bboxes: 100%|██████████| 1/1 [00:19<00:00, 19.49s/it]
# Recognizing Text: 100%|██████████| 2/2 [01:59<00:00, 59.70s/it]

# %%
predictions
# Out:
# [OCRResult(text_lines=[TextLine(polygon=[[55.0, 60.0], [304.0, 60.0], [304.0, 80.0], [55.0, 80.0]], confidence=0.98046875, text='KIWETINOHK ENERGY CORP.', bbox=[55.0, 60.0, 304.0, 80.0]), TextLine(polygon=[[986.0, 62.0], [1167.0, 62.0], [1167.0, 81.0], [986.0, 81.0]], confidence=0.9970703125, text='1/23/2023 7:50:46 AM', bbox=[986.0, 62.0, 1167.0, 81.0]), TextLine(polygon=[[1067.0, 82.0], [1167.0, 82.0], [1167.0, 99.0], [1067.0, 99.0]], confidence=0.99755859375, text='Page 1 of 25', bbox=[1067.0, 82.0, 1167.0, 99.0]), TextLine(polygon=[[54.0, 86.0], [484.0, 86.0], [484.0, 123.0], [54.0, 123.0]], confidence=0.9912109375, text='Addendum Detail Report', bbox=[54.0, 86.0, 484.0, 123.0]), TextLine(polygon=[[55.0, 129.0], [649.0, 129.0], [649.0, 151.0], [55.0, 151.0]], confidence=1.0, text='List of projects for the period October 26, 2023 to November 23, 2023', bbox=[55.0, 129.0, 649.0, 151.0]), TextLine(polygon=[[65.0, 169.0], [157.0, 169.0], [157.0, 187.0], [65.0, 187.0]], confidence=0.95556640625, text='Addendums', bbox=[65.0, 169.0, 157.0, 187.0]), TextLine(polygon=[[112.0, 204.0], [285.0, 204.0], [285.0, 222.0], [112.0, 222.0]], confidence=0.9853515625, text='Addendum Information', bbox=[112.0, 204.0, 285.0, 222.0]), TextLine(polygon=[[904.0, 205.0], [1130.0, 205.0], [1130.0, 222.0], [904.0, 222.0]], confidence=0.99951171875, text='Master Agreement Information', bbox=[904.0, 205.0, 1130.0, 222.0]), TextLine(polygon=[[770.0, 230.0], [879.0, 230.0], [879.0, 247.0], [770.0, 247.0]], confidence=0.98095703125, text='NW 20-062-24', bbox=[770.0, 230.0, 879.0, 247.0]), TextLine(polygon=[[243.0, 231.0], [337.0, 231.0], [337.0, 247.0], [243.0, 247.0]], confidence=0.9951171875, text='R00015-018', bbox=[243.0, 231.0, 337.0, 247.0]), TextLine(polygon=[[375.0, 231.0], [458.0, 231.0], [458.0, 247.0], [375.0, 247.0]], confidence=0.9951171875, text='Field Office', bbox=[375.0, 231.0, 458.0, 247.0]), TextLine(polygon=[[1034.0, 231.0], [1136.0, 231.0], [1136.0, 247.0], [1034.0, 247.0]], confidence=0.9873046875, text='BLUE RIDGE', bbox=[1034.0, 231.0, 1136.0, 247.0]), TextLine(polygon=[[111.0, 232.0], [172.0, 232.0], [172.0, 247.0], [111.0, 247.0]], confidence=0.9931640625, text='Number', bbox=[111.0, 232.0, 172.0, 247.0]), TextLine(polygon=[[639.0, 232.0], [724.0, 232.0], [724.0, 247.0], [639.0, 247.0]], confidence=0.98779296875, text='Description', bbox=[639.0, 232.0, 724.0, 247.0]), TextLine(polygon=[[904.0, 232.0], [965.0, 232.0], [965.0, 247.0], [904.0, 247.0]], confidence=0.9755859375, text='Grantee', bbox=[904.0, 232.0, 965.0, 247.0]), TextLine(polygon=[[771.0, 248.0], [884.0, 248.0], [884.0, 265.0], [771.0, 265.0]], confidence=0.97314453125, text='W5M TO SE 17', bbox=[771.0, 248.0, 884.0, 265.0]), TextLine(polygon=[[1034.0, 249.0], [1140.0, 249.0], [1140.0, 266.0], [1034.0, 266.0]], confidence=0.9921875, text='LUMBER INC.', bbox=[1034.0, 249.0, 1140.0, 266.0]), TextLine(polygon=[[110.0, 260.0], [208.0, 260.0], [208.0, 276.0], [110.0, 276.0]], confidence=0.9912109375, text='Project Type', bbox=[110.0, 260.0, 208.0, 276.0]), TextLine(polygon=[[243.0, 260.0], [304.0, 260.0], [304.0, 277.0], [243.0, 277.0]], confidence=0.9892578125, text='Logging', bbox=[243.0, 260.0, 304.0, 277.0]), TextLine(polygon=[[375.0, 260.0], [411.0, 260.0], [411.0, 275.0], [375.0, 275.0]], confidence=0.923828125, text='UWI', bbox=[375.0, 260.0, 411.0, 275.0]), TextLine(polygon=[[772.0, 265.0], [875.0, 265.0], [875.0, 283.0], [772.0, 283.0]], confidence=0.99658203125, text='-062-24 W5M;', bbox=[772.0, 265.0, 875.0, 283.0]), TextLine(polygon=[[1034.0, 266.0], [1104.0, 266.0], [1104.0, 283.0], [1034.0, 283.0]], confidence=0.9931640625, text='(101176)', bbox=[1034.0, 266.0, 1104.0, 283.0]), TextLine(polygon=[[772.0, 283.0], [878.0, 283.0], [878.0, 299.0], [772.0, 299.0]], confidence=0.9921875, text='SW 33-062-24', bbox=[772.0, 283.0, 878.0, 299.0]), TextLine(polygon=[[772.0, 301.0], [885.0, 301.0], [885.0, 318.0], [772.0, 318.0]], confidence=0.99560546875, text='W5M TO SE ...
