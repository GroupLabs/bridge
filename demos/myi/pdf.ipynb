# %%
# To read the PDF
import PyPDF2
# To analyze the PDF layout and extract text
from pdfminer.high_level import extract_pages, extract_text
from pdfminer.layout import LTTextContainer, LTChar, LTRect, LTFigure
# To extract text from tables in PDF
import pdfplumber
# To extract the images from the PDFs
from PIL import Image
from pdf2image import convert_from_path
# To perform OCR to extract text from images 
import pytesseract 
# To remove the additional created files
import os

# %%
# Create a function to extract text

def text_extraction(element):
    # Extracting the text from the in-line text element
    line_text = element.get_text()
    
    # Find the formats of the text
    # Initialize the list with all the formats that appeared in the line of text
    line_formats = []
    for text_line in element:
        if isinstance(text_line, LTTextContainer):
            # Iterating through each character in the line of text
            for character in text_line:
                if isinstance(character, LTChar):
                    # Append the font name of the character
                    line_formats.append(character.fontname)
                    # Append the font size of the character
                    line_formats.append(character.size)
    # Find the unique font sizes and names in the line
    format_per_line = list(set(line_formats))
    
    # Return a tuple with the text in each line along with its format
    return (line_text, format_per_line)

# %%
# Create a function to crop the image elements from PDFs
def crop_image(element, pageObj):
    # Get the coordinates to crop the image from the PDF
    [image_left, image_top, image_right, image_bottom] = [element.x0,element.y0,element.x1,element.y1] 
    # Crop the page using coordinates (left, bottom, right, top)
    pageObj.mediabox.lower_left = (image_left, image_bottom)
    pageObj.mediabox.upper_right = (image_right, image_top)
    # Save the cropped page to a new PDF
    cropped_pdf_writer = PyPDF2.PdfWriter()
    cropped_pdf_writer.add_page(pageObj)
    # Save the cropped PDF to a new file
    with open('cropped_image.pdf', 'wb') as cropped_pdf_file:
        cropped_pdf_writer.write(cropped_pdf_file)

# Create a function to convert the PDF to images
def convert_to_images(input_file,):
    images = convert_from_path(input_file)
    image = images[0]
    output_file = "PDF_image.png"
    image.save(output_file, "PNG")

# Create a function to read text from images
def image_to_text(image_path):
    # Read the image
    img = Image.open(image_path)
    # Extract the text from the image
    text = pytesseract.image_to_string(img)
    return text

# %%
def extract_table(pdf_path, page_num, table_num):
    # Open the pdf file
    pdf = pdfplumber.open(pdf_path)
    # Find the examined page
    table_page = pdf.pages[page_num]
    # Extract the appropriate table
    table = table_page.extract_tables()[table_num]
    return table

# Convert table into the appropriate format
def table_converter(table):
    table_string = ''
    # Iterate through each row of the table
    for row_num in range(len(table)):
        row = table[row_num]
        # Remove the line breaker from the wrapped texts
        cleaned_row = [item.replace('\n', ' ') if item is not None and '\n' in item else 'None' if item is None else item for item in row]
        # Convert the table into a string 
        table_string+=('|'+'|'.join(cleaned_row)+'|'+'\n')
    # Removing the last line break
    table_string = table_string[:-1]
    return table_string

# %%
# Find the PDF path
pdf_path = 'test2.pdf'

# create a PDF file object
pdfFileObj = open(pdf_path, 'rb')
# create a PDF reader object
pdfReaded = PyPDF2.PdfReader(pdfFileObj)

# Create the dictionary to extract text from each image
text_per_page = {}
# We extract the pages from the PDF
for pagenum, page in enumerate(extract_pages(pdf_path)):
    
    # Initialize the variables needed for the text extraction from the page
    pageObj = pdfReaded.pages[pagenum]
    page_text = []
    line_format = []
    text_from_images = []
    text_from_tables = []
    page_content = []
    # Initialize the number of the examined tables
    table_num = 0
    first_element= True
    table_extraction_flag= False
    # Open the pdf file
    pdf = pdfplumber.open(pdf_path)
    # Find the examined page
    page_tables = pdf.pages[pagenum]
    # Find the number of tables on the page
    tables = page_tables.find_tables()


    # Find all the elements
    page_elements = [(element.y1, element) for element in page._objs]
    # Sort all the elements as they appear in the page 
    page_elements.sort(key=lambda a: a[0], reverse=True)

    # Find the elements that composed a page
    for i,component in enumerate(page_elements):
        # Extract the position of the top side of the element in the PDF
        pos= component[0]
        # Extract the element of the page layout
        element = component[1]
        
        # Check if the element is a text element
        if isinstance(element, LTTextContainer):
            # Check if the text appeared in a table
            if table_extraction_flag == False:
                # Use the function to extract the text and format for each text element
                (line_text, format_per_line) = text_extraction(element)
                # Append the text of each line to the page text
                page_text.append(line_text)
                # Append the format for each line containing text
                line_format.append(format_per_line)
                page_content.append(line_text)
            else:
                # Omit the text that appeared in a table
                pass

        # Check the elements for images
        if isinstance(element, LTFigure):
            # Crop the image from the PDF
            crop_image(element, pageObj)
            # Convert the cropped pdf to an image
            convert_to_images('cropped_image.pdf')
            # Extract the text from the image
            image_text = image_to_text('PDF_image.png')
            text_from_images.append(image_text)
            page_content.append(image_text)
            # Add a placeholder in the text and format lists
            page_text.append('image')
            line_format.append('image')

        # Check the elements for tables
        if isinstance(element, LTRect):
            # If the first rectangular element
            if first_element == True and (table_num+1) <= len(tables):
                # Find the bounding box of the table
                lower_side = page.bbox[3] - tables[table_num].bbox[3]
                upper_side = element.y1 
                # Extract the information from the table
                table = extract_table(pdf_path, pagenum, table_num)
                # Convert the table information in structured string format
                table_string = table_converter(table)
                # Append the table string into a list
                text_from_tables.append(table_string)
                page_content.append(table_string)
                # Set the flag as True to avoid the content again
                table_extraction_flag = True
                # Make it another element
                first_element = False
                # Add a placeholder in the text and format lists
                page_text.append('table')
                line_format.append('table')

            # Check if we already extracted the tables from the page
            if element.y0 >= lower_side and element.y1 <= upper_side:
                pass
            elif not isinstance(page_elements[i+1][1], LTRect):
                table_extraction_flag = False
                first_element = True
                table_num+=1


    # Create the key of the dictionary
    dctkey = 'Page_'+str(pagenum)
    # Add the list of list as the value of the page key
    text_per_page[dctkey]= [page_text, line_format, text_from_images,text_from_tables, page_content]

# Closing the pdf file object
pdfFileObj.close()

# Deleting the additional files created
os.remove('cropped_image.pdf')
os.remove('PDF_image.png')

# Display the content of the page
result = ''.join(text_per_page['Page_0'][4])
print(result)
# Out:
# 8380070555
#
# 2 + 801 Fraser Street Irwin's Safety & Industrial Labour Services Ltd.
# Prince Rupert, BC, V8J 1R1
# GST Number: 813.517.695 Mar 28, 2022
# s&s WIN'S Phone: 250.624.8353
#
# E-mail: ar@irwinsafety.com
# INDUSTRIAL SAFETY
#
# ~ ~ http://www. irwinsafety.com/
# Tribal Resources Investment Corporation Estimate created by Natalya Townsend
# P.O. Box 339 V8J 1G6 ntownsend@irwinsafety.com
#
# Memory Brown
# mbrown@tricorp.ca
#
# Site Address: Gitsegukla Learning Centre: 155 Cascade Ave, Kitwanga, BC VOJ 2A0
#
# Terms: Net 30 Estimate # E-BCC-PRU 427
#
# Thank you for this opportunity to deliver training to Tribal Resources Investment Corporation. We are
# pleased to provide you a solution that we think will meet your needs. We have included the description of
# the course and the costs below.
#
# Irwin’s Safety is committed to protecting people's health and safety. To ensure all hazards and risks have
# been identified, all our training sites have been Hazard assessed with appropriate risk control measures put
# in place. Those measures include reasonable steps to protect staff, learners and others from Coronavirus
# (COVID-19) within our educational settings. Irwin’s Safety requires Tribal Resources Investment
# Corporation to coordinate all Covid-19 Assessments and protocols in order to safeguard students when
# conducting training on premises not under our control. In the absence of such protocols, Tribal Resources
# Investment Corporation will assume all COVID-19 associated liabilities.
#
# Name Price (CAD) Qty Subtotal
#
# Training
#
# Basic Security Guard Training $750.00 12
# Length: 5 days
# Minimum Participants: 12
#
# $9,000.00
#
# Maximum Participants:12
#
# Document Ref: JZUWI-Y3UYJ-FAKTG-XBSBZ Page 1 of 4
# 8380070555
# ~~
# fo WIN'S
#
# INDUSTRIAL SAFETY
#
# .
# 801 Fraser Street                               Irwin's Safety & Industrial Labour Services Ltd.
# Prince Rupert, BC, V8J 1R1
# GST Number: 813.517.695                                    Mar 28, 2022
# Phone: 250.624.8353
# E-mail: ar@irwinsafety.com
# http://www.irwinsafety.com/
# |8380070555 801 Fraser Street Irwin's Safety & Industrial Labour Services Ltd. Prince Rupert, BC, V8J 1R1 GST Number: 813.517.695 Mar 28, 2022 Phone: 250.624.8353 E-mail: ar@irwinsafety.com http://www.irwinsafety.com/ Tribal Resources Investment Corporation Estimate created by Natalya Townsend P.O. Box 339 V8J 1G6 ntownsend@irwinsafety.com Memory Brown mbrown@tricorp.ca Site Address: Gitsegukla Learning Centre: 155 Cascade Ave, Kitwanga, BC V0J 2A0 Terms: N e t 3 0 Estimate # E-BCC-PRU 427 Thank you for this opportunity to deliver training to Tribal Resources Investment Corporation. We are pleased to provide you a solution that we think will meet your needs. We have included the description of the course and the costs below. Irwin’s Safety is committed to protecting people's health and safety. To ensure all hazards and risks have been identified, all our training sites have been Hazard assessed with appropriate risk control measures put in place. Those measures include reasonable steps to protect staff, learners and others from Coronavirus (COVID-19) within our educational settings. Irwin’s Safety requires Tribal Resources Investment Corporation to coordinate all Covid-19 Assessments and protocols in order to safeguard students when conducting training on premises not under our control. In the absence of such protocols, Tribal Resources Investment Corporation will assume all COVID-19 associated liabilities. Name Price (CAD) Qty Subtotal Training Basic Security Guard Training $750.00 12 $9,000.00 Length: 5 days Minimum Participants: 12 Maximum Participants:12 Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ Page 1 of 4|None|None|
# |Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ|Page 1 of 4||Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ
# Page 1 of 4

# %%
text_per_page
# Out:
# {'Page_0': [['image',
#    '8380070555\n',
#    'image',
#    "801 Fraser Street                               Irwin's Safety & Industrial Labour Services Ltd.\n",
#    'Prince Rupert, BC, V8J 1R1\nGST Number: 813.517.695                                    Mar 28, 2022\nPhone: 250.624.8353\nE-mail: ar@irwinsafety.com                                 \n',
#    'http://www.irwinsafety.com/\n',
#    'table',
#    'Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ\n',
#    'Page 1 of 4\n'],
#   ['image',
#    [10.49999956250008, 'ArialMT'],
#    'image',
#    [8.999999624999987, 'Arial-BoldMT', 'ArialMT'],
#    [8.999999624999987, 11.999999499999944, 'ArialMT'],
#    [8.999999624999987, 'ArialMT'],
#    'table',
#    ['AAANUD+ArialUnicodeMS', 7.000000000000001],
#    ['AAANUD+ArialUnicodeMS', 7.000000000000001]],
#   ["8380070555\n\n2 + 801 Fraser Street Irwin's Safety & Industrial Labour Services Ltd.\nPrince Rupert, BC, V8J 1R1\nGST Number: 813.517.695 Mar 28, 2022\ns&s WIN'S Phone: 250.624.8353\n\nE-mail: ar@irwinsafety.com\nINDUSTRIAL SAFETY\n\n~ ~ http://www. irwinsafety.com/\nTribal Resources Investment Corporation Estimate created by Natalya Townsend\nP.O. Box 339 V8J 1G6 ntownsend@irwinsafety.com\n\nMemory Brown\nmbrown@tricorp.ca\n\nSite Address: Gitsegukla Learning Centre: 155 Cascade Ave, Kitwanga, BC VOJ 2A0\n\nTerms: Net 30 Estimate # E-BCC-PRU 427\n\nThank you for this opportunity to deliver training to Tribal Resources Investment Corporation. We are\npleased to provide you a solution that we think will meet your needs. We have included the description of\nthe course and the costs below.\n\nIrwin’s Safety is committed to protecting people's health and safety. To ensure all hazards and risks have\nbeen identified, all our training sites have been Hazard assessed with appropriate risk control measures put\nin place. Those measures include reasonable steps to protect staff, learners and others from Coronavirus\n(COVID-19) within our educational settings. Irwin’s Safety requires Tribal Resources Investment\nCorporation to coordinate all Covid-19 Assessments and protocols in order to safeguard students when\nconducting training on premises not under our control. In the absence of such protocols, Tribal Resources\nInvestment Corporation will assume all COVID-19 associated liabilities.\n\nName Price (CAD) Qty Subtotal\n\nTraining\n\nBasic Security Guard Training $750.00 12\nLength: 5 days\nMinimum Participants: 12\n\n$9,000.00\n\nMaximum Participants:12\n\nDocument Ref: JZUWI-Y3UYJ-FAKTG-XBSBZ Page 1 of 4\n",
#    "~~\nfo WIN'S\n\nINDUSTRIAL SAFETY\n\n.\n"],
#   ["|8380070555 801 Fraser Street Irwin's Safety & Industrial Labour Services Ltd. Prince Rupert, BC, V8J 1R1 GST Number: 813.517.695 Mar 28, 2022 Phone: 250.624.8353 E-mail: ar@irwinsafety.com http://www.irwinsafety.com/ Tribal Resources Investment Corporation Estimate created by Natalya Townsend P.O. Box 339 V8J 1G6 ntownsend@irwinsafety.com Memory Brown mbrown@tricorp.ca Site Address: Gitsegukla Learning Centre: 155 Cascade Ave, Kitwanga, BC V0J 2A0 Terms: N e t 3 0 Estimate # E-BCC-PRU 427 Thank you for this opportunity to deliver training to Tribal Resources Investment Corporation. We are pleased to provide you a solution that we think will meet your needs. We have included the description of the course and the costs below. Irwin’s Safety is committed to protecting people's health and safety. To ensure all hazards and risks have been identified, all our training sites have been Hazard assessed with appropriate risk control measures put in place. Those measures include reasonable steps to protect staff, learners and others from Coronavirus (COVID-19) within our educational settings. Irwin’s Safety requires Tribal Resources Investment Corporation to coordinate all Covid-19 Assessments and protocols in order to safeguard students when conducting training on premises not under our control. In the absence of such protocols, Tribal Resources Investment Corporation will assume all COVID-19 associated liabilities. Name Price (CAD) Qty Subtotal Training Basic Security Guard Training $750.00 12 $9,000.00 Length: 5 days Minimum Participants: 12 Maximum Participants:12 Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ Page 1 of 4|None|None|\n|Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ|Page 1 of 4||"],
#   ["8380070555\n\n2 + 801 Fraser Street Irwin's Safety & Industrial Labour Services Ltd.\nPrince Rupert, BC, V8J 1R1\nGST Number: 813.517.695 Mar 28, 2022\ns&s WIN'S Phone: 250.624.8353\n\nE-mail: ar@irwinsafety.com\nINDUSTRIAL SAFETY\n\n~ ~ http://www. irwinsafety.com/\nTribal Resources Investment Corporation Estimate created by Natalya Townsend\nP.O. Box 339 V8J 1G6 ntownsend@irwinsafety.com\n\nMemory Brown\nmbrown@tricorp.ca\n\nSite Address: Gitsegukla Learning Centre: 155 Cascade Ave, Kitwanga, BC VOJ 2A0\n\nTerms: Net 30 Estimate # E-BCC-PRU 427\n\nThank you for this opportunity to deliver training to Tribal Resources Investment Corporation. We are\npleased to provide you a solution that we think will meet your needs. We have included the description of\nthe course and the costs below.\n\nIrwin’s Safety is committed to protecting people's health and safety. To ensure all hazards and risks have\nbeen identified, all our training sites have been Hazard assessed with appropriate risk control measures put\nin place. Those measures include reasonable steps to protect staff, learners and others from Coronavirus\n(COVID-19) within our educational settings. Irwin’s Safety requires Tribal Resources Investment\nCorporation to coordinate all Covid-19 Assessments and protocols in order to safeguard students when\nconducting training on premises not under our control. In the absence of such protocols, Tribal Resources\nInvestment Corporation will assume all COVID-19 associated liabilities.\n\nName Price (CAD) Qty Subtotal\n\nTraining\n\nBasic Security Guard Training $750.00 12\nLength: 5 days\nMinimum Participants: 12\n\n$9,000.00\n\nMaximum Participants:12\n\nDocument Ref: JZUWI-Y3UYJ-FAKTG-XBSBZ Page 1 of 4\n",
#    '8380070555\n',
#    "~~\nfo WIN'S\n\nINDUSTRIAL SAFETY\n\n.\n",
#    "801 Fraser Street                               Irwin's Safety & Industrial Labour Services Ltd.\n",
#    'Prince Rupert, BC, V8J 1R1\nGST Number: 813.517.695                                    Mar 28, 2022\nPhone: 250.624.8353\nE-mail: ar@irwinsafety.com                                 \n',
#    'http://www.irwinsafety.com/\n',
#    "|8380070555 801 Fraser Street Irwin's Safety & Industrial Labour Services Ltd. Prince Rupert, BC, V8J 1R1 GST Number: 813.517.695 Mar 28, 2022 Phone: 250.624.8353 E-mail: ar@irwinsafety.com http://www.irwinsafety.com/ Tribal Resources Investment Corporation Estimate created by Natalya Townsend P.O. Box 339 V8J 1G6 ntownsend@irwinsafety.com Memory Brown mbrown@tricorp.ca Site Address: Gitsegukla Learning Centre: 155 Cascade Ave, Kitwanga, BC V0J 2A0 Terms: N e t 3 0 Estimate # E-BCC-PRU 427 Thank you for this opportunity to deliver training to Tribal Resources Investment Corporation. We are pleased to provide you a solution that we think will meet your needs. We have included the description of the course and the costs below. Irwin’s Safety is committed to protecting people's health and safety. To ensure all hazards and risks have been identified, all our training sites have been Hazard assessed with appropriate risk control measures put in place. Those measures include reasonable steps to protect staff, learners and others from Coronavirus (COVID-19) within our educational settings. Irwin’s Safety requires Tribal Resources Investment Corporation to coordinate all Covid-19 Assessments and protocols in order to safeguard students when conducting training on premises not under our control. In the absence of such protocols, Tribal Resources Investment Corporation will assume all COVID-19 associated liabilities. Name Price (CAD) Qty Subtotal Training Basic Security Guard Training $750.00 12 $9,000.00 Length: 5 days Minimum Participants: 12 Maximum Participants:12 Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ Page 1 of 4|None|None|\n|Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ|Page 1 of 4||",
#    'Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ\n',
#    'Page 1 of 4\n']],
#  'Page_1': [['image',
#    'table',
#    'Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ\n',
#    'Page 2 of 4\n'],
#   ['image',
#    'table',
#    ['AAANUD+ArialUnicodeMS', 7.000000000000001],
#    ['AAANUD+ArialUnicodeMS', 7.000000000000001]],
#   ["Exam Fee\n\nIf students fail and student wants to\ncomplete another exam there will be an\nadditional fee.\n\n$165.00\n\n12\n\n$1,980.00\n\nBasic Security Guard Training License\napplication form. 3 Years.\n\nIrwin's will assist with the online application\nincluding photograph. Does NOT include\nfingerprints. Participants will need to apply\nby going to local police detachment for\nfingerprints at a later time depending on\npandemic. Licensing may take up to 6\nweeks to process an application.\n\n$450.00\n\n$450.00\n\nIncidentals\n\nTravel\n\nLiving Out Allowance\n\n$1,000.00\n\n$250.00\n\n$1,000.00\n\n$1,250.00\n\nFreight & Duties\n\n$0.00\n\n$0.00\n\nSubtotal\n\nTotal\n\n$13,680.00\n\n$13,680.00\n\nIn the field below, please provide Tribal Resources Investment Corporation's mailing address to be used by\nus to mail you permanent certificates issued by Irwin's Safety.\n\nBox 339, Prince Rupert, BC V8J 3P9\n\nTerms and Conditions\n\nIncorporation of Terms: These terms and conditions govern the agreement that is formed by acceptance of\n\nthe estimate.\n\n1. Services: Upon acceptance of the estimate, Irwin’s will perform the training or other services\n\ndescribed in the estimate. Any additional services requested that are not covered by the estimate\n\nmay incur additional charges and must be agreed upon in writing by both parties.\n\n2. Shipping and freight: Costs associated with mobilizing materials and equipment to the customer’s\n\nDocument Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ\n\nPage 2 of 4\n"],
#   ["|Exam Fee $165.00 12 $1,980.00 If students fail and student wants to complete another exam there will be an additional fee. Basic Security Guard Training License $450.00 1 $450.00 application form. 3 Years. Irwin's will assist with the online application including photograph. Does NOT include fingerprints. Participants will need to apply by going to local police detachment for fingerprints at a later time depending on pandemic. Licensing may take up to 6 weeks to process an application. Incidentals Travel $1,000.00 1 $1,000.00 Living Out Allowance $250.00 5 $1,250.00 Freight & Duties $0.00 1 $0.00 Subtotal $13,680.00 Total $13,680.00 In the field below, please provide Tribal Resources Investment Corporation's mailing address to be used by us to mail you permanent certificates issued by Irwin's Safety. Box 339, Prince Rupert, BC V8J 3P9 Terms and Conditions Incorporation of Terms: These terms and conditions govern the agreement that is formed by acceptance of the estimate. 1. Services: Upon acceptance of the estimate, Irwin’s will perform the training or other services described in the estimate. Any additional services requested that are not covered by the estimate may incur additional charges and must be agreed upon in writing by both parties. 2. Shipping and freight: Costs associated with mobilizing materials and equipment to the customer’s Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ Page 2 of 4|None|None|\n|Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ|Page 2 of 4||"],
#   ["Exam Fee\n\nIf students fail and student wants to\ncomplete another exam there will be an\nadditional fee.\n\n$165.00\n\n12\n\n$1,980.00\n\nBasic Security Guard Training License\napplication form. 3 Years.\n\nIrwin's will assist with the online application\nincluding photograph. Does NOT include\nfingerprints. Participants will need to apply\nby going to local police detachment for\nfingerprints at a later time depending on\npandemic. Licensing may take up to 6\nweeks to process an application.\n\n$450.00\n\n$450.00\n\nIncidentals\n\nTravel\n\nLiving Out Allowance\n\n$1,000.00\n\n$250.00\n\n$1,000.00\n\n$1,250.00\n\nFreight & Duties\n\n$0.00\n\n$0.00\n\nSubtotal\n\nTotal\n\n$13,680.00\n\n$13,680.00\n\nIn the field below, please provide Tribal Resources Investment Corporation's mailing address to be used by\nus to mail you permanent certificates issued by Irwin's Safety.\n\nBox 339, Prince Rupert, BC V8J 3P9\n\nTerms and Conditions\n\nIncorporation of Terms: These terms and conditions govern the agreement that is formed by acceptance of\n\nthe estimate.\n\n1. Services: Upon acceptance of the estimate, Irwin’s will perform the training or other services\n\ndescribed in the estimate. Any additional services requested that are not covered by the estimate\n\nmay incur additional charges and must be agreed upon in writing by both parties.\n\n2. Shipping and freight: Costs associated with mobilizing materials and equipment to the customer’s\n\nDocument Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ\n\nPage 2 of 4\n",
#    "|Exam Fee $165.00 12 $1,980.00 If students fail and student wants to complete another exam there will be an additional fee. Basic Security Guard Training License $450.00 1 $450.00 application form. 3 Years. Irwin's will assist with the online application including photograph. Does NOT include fingerprints. Participants will need to apply by going to local police detachment for fingerprints at a later time depending on pandemic. Licensing may take up to 6 weeks to process an application. Incidentals Travel $1,000.00 1 $1,000.00 Living Out Allowance $250.00 5 $1,250.00 Freight & Duties $0.00 1 $0.00 Subtotal $13,680.00 Total $13,680.00 In the field below, please provide Tribal Resources Investment Corporation's mailing address to be used by us to mail you permanent certificates issued by Irwin's Safety. Box 339, Prince Rupert, BC V8J 3P9 Terms and Conditions Incorporation of Terms: These terms and conditions govern the agreement that is formed by acceptance of the estimate. 1. Services: Upon acceptance of the estimate, Irwin’s will perform the training or other services described in the estimate. Any additional services requested that are not covered by the estimate may incur additional charges and must be agreed upon in writing by both parties. 2. Shipping and freight: Costs associated with mobilizing materials and equipment to the customer’s Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ Page 2 of 4|None|None|\n|Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ|Page 2 of 4||",
#    'Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ\n',
#    'Page 2 of 4\n']],
#  'Page_2': [['image',
#    'location will be charged based upon actual costs when described in the estimate.\n',
#    "3.  Travel: Irwin's instructors are sourced to meet customer needs, schedule, location, and \n",
#    'budget. Instructor travel may be required relative to where the training and the suitable instructor is \n',
#    'located. Additional costs for instructor travel may include: travel time and mileage, reasonable \n',
#    'accommodations, transportation, meal allowance and must be agreed to in writing.\n',
#    '4.  Unless otherwise specified, this is not a fixed price agreement. Services are rendered on a time & \n',
#    'materials basis. \n',
#    '5.  Taxes: All prices are subject to applicable Provincial and Federal Sales tax. No tax exemption will be \n',
#    'recognized unless a valid exemption certificate is provided.\n',
#    '6.  Late Charges: Invoice will be subject to 2% charge if payment is late by a duration of 30 days or \n',
#    'fewer, and an additional 2.5% for each additional 30 days late.\n',
#    '7.  Advance Payment: Irwin’s may, in its discretion, require a partial payment in advance for any project.\n',
#    '8. \n',
#    'Incidentals and consumables are charged at cost +10% unless otherwise specified in the agreement \n',
#    'with the consumer.\n',
#    '9.  Once a signed estimate or PO is received, any cancellations will be charged an administration fee of \n',
#    '$350/course. Customers canceling less than 2 business days before the course start will be billed \n',
#    '50% of the courses to be credited towards future training minus administration fees and any travel \n',
#    'costs.\n',
#    '10. Upon completion of training, Temporary training certificates, valid for 60 days, will be issued to the \n',
#    'customer for distribution.*\n',
#    '11. Permanent tickets will be issued to the customer directly for distribution upon receipt of full payment \n',
#    'for the training. Please allow for printing and shipping time to receive permanent tickets.\n',
#    "12. An accurate student roster of full, legal names will be requested from the customer prior to training. \nTraining certificates issued by Irwin's will match the names as they appear on government IDs. \nCertificates will undergo a quality check for accuracy at the printing phase against the list supplied. \nRe-prints due to errors discovered after this point will be at the expense of the client.\n",
#    ' \n',
#    '*Some certifying bodies (i.e. Energy Safety Canada) issue only permanent tickets and only directly to \nthe students. No temporary tickets are provided in the meantime\n',
#    ' \n',
#    'Miscellaneous Provisions.\n',
#    ' \n',
#    'Amendments: Any amendments to the estimate or these terms will be effective only if in writing and signed \n',
#    'by authorized representatives of both parties.\n',
#    ' \n',
#    'Confidential and proprietary information: All non-public, confidential or proprietary information of the parties, \n',
#    'their employees or contractors including but not limited to documents, data, business operations, customer \n',
#    'lists, pricing, discounts or rebates, disclosed by Seller to Buyer, whether disclosed orally or disclosed or \n',
#    'accessed in written, electronic or other form or media, and whether or not marked, designated or otherwise \n',
#    'table',
#    'Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ\n',
#    'Page 3 of 4\n'],
#   ['image',
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531250012, 'ArialMT'],
#    [11.249999531250012, 'ArialMT'],
#    [11.249999531250012, 'ArialMT'],
#    [11.249999531250012, 'ArialMT'],
#    [11.249999531250012, 'ArialMT'],
#    [11.249999531250012, 'ArialMT'],
#    [11.249999531250012, 'ArialMT'],
#    [11.249999531250012, 'ArialMT'],
#    [11.249999531250012, 'ArialMT'],
#    [11.249999531250012, 'ArialMT'],
#    [],
#    [11.249999531250012, 'ArialMT'],
#    [],
#    [11.249999531250012, 'ArialMT'],
#    [],
#    [11.249999531250012, 'ArialMT'],
#    [11.249999531250012, 'ArialMT'],
#    [],
#    [11.249999531250012, 'ArialMT'],
#    [11.249999531249998, 'ArialMT'],
#    [11.249999531249998, 'ArialMT'],
#    [11.249999531249998, 'ArialMT'],
#    'table',
#    ['AAANUD+ArialUnicodeMS', 7.000000000000001],
#    ['AAANUD+ArialUnicodeMS', 7.000000000000001]],
#   ["location will be charged based upon actual costs when described in the estimate.\n\n3. Travel: Irwin's instructors are sourced to meet customer needs, schedule, location, and\nbudget. Instructor travel may be required relative to where the training and the suitable instructor is\nlocated. Additional costs for instructor travel may include: travel time and mileage, reasonable\naccommodations, transportation, meal allowance and must be agreed to in writing.\n\n4. Unless otherwise specified, this is not a fixed price agreement. Services are rendered on a time &\nmaterials basis.\n\n5. Taxes: All prices are subject to applicable Provincial and Federal Sales tax. No tax exemption will be\nrecognized unless a valid exemption certificate is provided.\n\n6. Late Charges: Invoice will be subject to 2% charge if payment is late by a duration of 30 days or\nfewer, and an additional 2.5% for each additional 30 days late.\n\nAdvance Payment: Irwin’s may, in its discretion, require a partial payment in advance for any project.\nIncidentals and consumables are charged at cost +10% unless otherwise specified in the agreement\nwith the consumer.\n\n9. Once a signed estimate or PO is received, any cancellations will be charged an administration fee of\n$350/course. Customers canceling less than 2 business days before the course start will be billed\n50% of the courses to be credited towards future training minus administration fees and any travel\ncosts.\n\n10. Upon completion of training, Temporary training certificates, valid for 60 days, will be issued to the\ncustomer for distribution.*\n\n11. Permanent tickets will be issued to the customer directly for distribution upon receipt of full payment\nfor the training. Please allow for printing and shipping time to receive permanent tickets.\n\n12. An accurate student roster of full, legal names will be requested from the customer prior to training.\nTraining certificates issued by Irwin's will match the names as they appear on government IDs.\nCertificates will undergo a quality check for accuracy at the printing phase against the list supplied.\nRe-prints due to errors discovered after this point will be at the expense of the client.\n\n*Some certifying bodies (i.e. Energy Safety Canada) issue only permanent tickets and only directly to\nthe students. No temporary tickets are provided in the meantime\n\nMiscellaneous Provisions.\n\nAmendments: Any amendments to the estimate or these terms will be effective only if in writing and signed\nby authorized representatives of both parties.\n\nConfidential and proprietary information: All non-public, confidential or proprietary information of the parties,\ntheir employees or contractors including but not limited to documents, data, business operations, customer\nlists, pricing, discounts or rebates, disclosed by Seller to Buyer, whether disclosed orally or disclosed or\n\naccessed in written, electronic or other form or media, and whether or not marked, designated or otherwise\n\nDocument Ref: JZUWI-Y3UYJ-FAKTG-XBSBZ Page 3 of 4\n"],
#   ["|location will be charged based upon actual costs when described in the estimate. 3. Travel: Irwin's instructors are sourced to meet customer needs, schedule, location, and budget. Instructor travel may be required relative to where the training and the suitable instructor is located. Additional costs for instructor travel may include: travel time and mileage, reasonable accommodations, transportation, meal allowance and must be agreed to in writing. 4. Unless otherwise specified, this is not a fixed price agreement. Services are rendered on a time & materials basis. 5. Taxes: All prices are subject to applicable Provincial and Federal Sales tax. No tax exemption will be recognized unless a valid exemption certificate is provided. 6. Late Charges: Invoice will be subject to 2% charge if payment is late by a duration of 30 days or fewer, and an additional 2.5% for each additional 30 days late. 7. Advance Payment: Irwin’s may, in its discretion, require a partial payment in advance for any project. 8. Incidentals and consumables are charged at cost +10% unless otherwise specified in the agreement with the consumer. 9. Once a signed estimate or PO is received, any cancellations will be charged an administration fee of $350/course. Customers canceling less than 2 business days before the course start will be billed 50% of the courses to be credited towards future training minus administration fees and any travel costs. 10. Upon completion of training, Temporary training certificates, valid for 60 days, will be issued to the customer for distribution.* 11. Permanent tickets will be issued to the customer directly for distribution upon receipt of full payment for the training. Please allow for printing and shipping time to receive permanent tickets. 12. An accurate student roster of full, legal names will be requested from the customer prior to training. Training certificates issued by Irwin's will match the names as they appear on government IDs. Certificates will undergo a quality check for accuracy at the printing phase against the list supplied. Re-prints due to errors discovered after this point will be at the expense of the client. *Some certifying bodies (i.e. Energy Safety Canada) issue only permanent tickets and only directly to the students. No temporary tickets are provided in the meantime Miscellaneous Provisions. Amendments: Any amendments to the estimate or these terms will be effective only if in writing and signed by authorized representatives of both parties. Confidential and proprietary information: All non-public, confidential or proprietary information of the parties, their employees or contractors including but not limited to documents, data, business operations, customer lists, pricing, discounts or rebates, disclosed by Seller to Buyer, whether disclosed orally or disclosed or accessed in written, electronic or other form or media, and whether or not marked, designated or otherwise Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ Page 3 of 4|None|None|\n|Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ|Page 3 of 4||"],
#   ["location will be charged based upon actual costs when described in the estimate.\n\n3. Travel: Irwin's instructors are sourced to meet customer needs, schedule, location, and\nbudget. Instructor travel may be required relative to where the training and the suitable instructor is\nlocated. Additional costs for instructor travel may include: travel time and mileage, reasonable\naccommodations, transportation, meal allowance and must be agreed to in writing.\n\n4. Unless otherwise specified, this is not a fixed price agreement. Services are rendered on a time &\nmaterials basis.\n\n5. Taxes: All prices are subject to applicable Provincial and Federal Sales tax. No tax exemption will be\nrecognized unless a valid exemption certificate is provided.\n\n6. Late Charges: Invoice will be subject to 2% charge if payment is late by a duration of 30 days or\nfewer, and an additional 2.5% for each additional 30 days late.\n\nAdvance Payment: Irwin’s may, in its discretion, require a partial payment in advance for any project.\nIncidentals and consumables are charged at cost +10% unless otherwise specified in the agreement\nwith the consumer.\n\n9. Once a signed estimate or PO is received, any cancellations will be charged an administration fee of\n$350/course. Customers canceling less than 2 business days before the course start will be billed\n50% of the courses to be credited towards future training minus administration fees and any travel\ncosts.\n\n10. Upon completion of training, Temporary training certificates, valid for 60 days, will be issued to the\ncustomer for distribution.*\n\n11. Permanent tickets will be issued to the customer directly for distribution upon receipt of full payment\nfor the training. Please allow for printing and shipping time to receive permanent tickets.\n\n12. An accurate student roster of full, legal names will be requested from the customer prior to training.\nTraining certificates issued by Irwin's will match the names as they appear on government IDs.\nCertificates will undergo a quality check for accuracy at the printing phase against the list supplied.\nRe-prints due to errors discovered after this point will be at the expense of the client.\n\n*Some certifying bodies (i.e. Energy Safety Canada) issue only permanent tickets and only directly to\nthe students. No temporary tickets are provided in the meantime\n\nMiscellaneous Provisions.\n\nAmendments: Any amendments to the estimate or these terms will be effective only if in writing and signed\nby authorized representatives of both parties.\n\nConfidential and proprietary information: All non-public, confidential or proprietary information of the parties,\ntheir employees or contractors including but not limited to documents, data, business operations, customer\nlists, pricing, discounts or rebates, disclosed by Seller to Buyer, whether disclosed orally or disclosed or\n\naccessed in written, electronic or other form or media, and whether or not marked, designated or otherwise\n\nDocument Ref: JZUWI-Y3UYJ-FAKTG-XBSBZ Page 3 of 4\n",
#    'location will be charged based upon actual costs when described in the estimate.\n',
#    "3.  Travel: Irwin's instructors are sourced to meet customer needs, schedule, location, and \n",
#    'budget. Instructor travel may be required relative to where the training and the suitable instructor is \n',
#    'located. Additional costs for instructor travel may include: travel time and mileage, reasonable \n',
#    'accommodations, transportation, meal allowance and must be agreed to in writing.\n',
#    '4.  Unless otherwise specified, this is not a fixed price agreement. Services are rendered on a time & \n',
#    'materials basis. \n',
#    '5.  Taxes: All prices are subject to applicable Provincial and Federal Sales tax. No tax exemption will be \n',
#    'recognized unless a valid exemption certificate is provided.\n',
#    '6.  Late Charges: Invoice will be subject to 2% charge if payment is late by a duration of 30 days or \n',
#    'fewer, and an additional 2.5% for each additional 30 days late.\n',
#    '7.  Advance Payment: Irwin’s may, in its discretion, require a partial payment in advance for any project.\n',
#    '8. \n',
#    'Incidentals and consumables are charged at cost +10% unless otherwise specified in the agreement \n',
#    'with the consumer.\n',
#    '9.  Once a signed estimate or PO is received, any cancellations will be charged an administration fee of \n',
#    '$350/course. Customers canceling less than 2 business days before the course start will be billed \n',
#    '50% of the courses to be credited towards future training minus administration fees and any travel \n',
#    'costs.\n',
#    '10. Upon completion of training, Temporary training certificates, valid for 60 days, will be issued to the \n',
#    'customer for distribution.*\n',
#    '11. Permanent tickets will be issued to the customer directly for distribution upon receipt of full payment \n',
#    'for the training. Please allow for printing and shipping time to receive permanent tickets.\n',
#    "12. An accurate student roster of full, legal names will be requested from the customer prior to training. \nTraining certificates issued by Irwin's will match the names as they appear on government IDs. \nCertificates will undergo a quality check for accuracy at the printing phase against the list supplied. \nRe-prints due to errors discovered after this point will be at the expense of the client.\n",
#    ' \n',
#    '*Some certifying bodies (i.e. Energy Safety Canada) issue only permanent tickets and only directly to \nthe students. No temporary tickets are provided in the meantime\n',
#    ' \n',
#    'Miscellaneous Provisions.\n',
#    ' \n',
#    'Amendments: Any amendments to the estimate or these terms will be effective only if in writing and signed \n',
#    'by authorized representatives of both parties.\n',
#    ' \n',
#    'Confidential and proprietary information: All non-public, confidential or proprietary information of the parties, \n',
#    'their employees or contractors including but not limited to documents, data, business operations, customer \n',
#    'lists, pricing, discounts or rebates, disclosed by Seller to Buyer, whether disclosed orally or disclosed or \n',
#    'accessed in written, electronic or other form or media, and whether or not marked, designated or otherwise \n',
#    "|location will be charged based upon actual costs when described in the estimate. 3. Travel: Irwin's instructors are sourced to meet customer needs, schedule, location, and budget. Instructor travel may be required relative to where the training and the suitable instructor is located. Additional costs for instructor travel may include: travel time and mileage, reasonable accommodations, transportation, meal allowance and must be agreed to in writing. 4. Unless otherwise specified, this is not a fixed price agreement. Services are rendered on a time & materials basis. 5. Taxes: All prices are subject to applicable Provincial and Federal Sales tax. No tax exemption will be recognized unless a valid exemption certificate is provided. 6. Late Charges: Invoice will be subject to 2% charge if payment is late by a duration of 30 days or fewer, and an additional 2.5% for each additional 30 days late. 7. Advance Payment: Irwin’s may, in its discretion, require a partial payment in advance for any project. 8. Incidentals and consumables are charged at cost +10% unless otherwise specified in the agreement with the consumer. 9. Once a signed estimate or PO is received, any cancellations will be charged an administration fee of $350/course. Customers canceling less than 2 business days before the course start will be billed 50% of the courses to be credited towards future training minus administration fees and any travel costs. 10. Upon completion of training, Temporary training certificates, valid for 60 days, will be issued to the customer for distribution.* 11. Permanent tickets will be issued to the customer directly for distribution upon receipt of full payment for the training. Please allow for printing and shipping time to receive permanent tickets. 12. An accurate student roster of full, legal names will be requested from the customer prior to training. Training certificates issued by Irwin's will match the names as they appear on government IDs. Certificates will undergo a quality check for accuracy at the printing phase against the list supplied. Re-prints due to errors discovered after this point will be at the expense of the client. *Some certifying bodies (i.e. Energy Safety Canada) issue only permanent tickets and only directly to the students. No temporary tickets are provided in the meantime Miscellaneous Provisions. Amendments: Any amendments to the estimate or these terms will be effective only if in writing and signed by authorized representatives of both parties. Confidential and proprietary information: All non-public, confidential or proprietary information of the parties, their employees or contractors including but not limited to documents, data, business operations, customer lists, pricing, discounts or rebates, disclosed by Seller to Buyer, whether disclosed orally or disclosed or accessed in written, electronic or other form or media, and whether or not marked, designated or otherwise Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ Page 3 of 4|None|None|\n|Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ|Page 3 of 4||",
#    'Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ\n',
#    'Page 3 of 4\n']],
#  'Page_3': [['image',
#    'identified as “confidential” in connection with this Agreement is confidential, solely for the use of performing \n',
#    'this Contract and may not be disclosed or copied unless authorized in advance by in writing. The \n',
#    'parties shall be entitled to injunctive relief for any violation of this section. This section does not apply to \n',
#    'information that is: (a) in the public domain; (b) known to Buyer at the time of disclosure; or (c) rightfully \n',
#    'obtained by Buyer on a non-confidential basis from a third party\n',
#    ' \n',
#    'Entire Agreement: The estimate and these terms (together with any schedules or exhibits attached) \n',
#    'constitute the entire agreement and understanding between the parties with respect to the subject matter \n',
#    'hereof, and supersede any previous agreements or understandings, whether oral or written.\n',
#    ' \n',
#    'By signing below, I confirm that I am authorized to bind the corporation.\n',
#    ' \n',
#    ' \n',
#    'image',
#    ' \n',
#    ' \n',
#    'Memory Brown\n',
#    'If you wish to decline this estimate, click on "Other Actions" in the top right corner and select "Decline"\n',
#    'table',
#    'Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ\n',
#    'Page 4 of 4\n'],
#   ['image',
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [11.249999531249955, 'ArialMT'],
#    [],
#    [11.249999531249955, 'ArialMT'],
#    [],
#    [],
#    'image',
#    [],
#    [],
#    [11.249999531250012, 'ArialMT'],
#    [10.499999562499966, 'Arial-BoldMT'],
#    'table',
#    ['AAANUD+ArialUnicodeMS', 7.000000000000001],
#    ['AAANUD+ArialUnicodeMS', 7.000000000000001]],
#   ['identified as “confidential” in connection with this Agreement is confidential, solely for the use of performing\nthis Contract and may not be disclosed or copied unless authorized in advance by in writing. The\n\nparties shall be entitled to injunctive relief for any violation of this section. This section does not apply to\ninformation that is: (a) in the public domain; (b) known to Buyer at the time of disclosure; or (c) rightfully\nobtained by Buyer on a non-confidential basis from a third party\n\nEntire Agreement: The estimate and these terms (together with any schedules or exhibits attached)\nconstitute the entire agreement and understanding between the parties with respect to the subject matter\n\nhereof, and supersede any previous agreements or understandings, whether oral or written.\n\nBy signing below, | confirm that | am authorized to bind the corporation.\n\nJacgqule Ridley\nMemory Brown\n\nIf you wish to decline this estimate, click on "Other Actions" in the top right corner and select "Decline"\n\nDocument Ref: JZUWI-Y3UYJ-FAKTG-XBSBZ Page 4 of 4\n',
#    'Jacquit Ridley\n'],
#   ['|identified as “confidential” in connection with this Agreement is confidential, solely for the use of performing this Contract and may not be disclosed or copied unless authorized in advance by in writing. The parties shall be entitled to injunctive relief for any violation of this section. This section does not apply to information that is: (a) in the public domain; (b) known to Buyer at the time of disclosure; or (c) rightfully obtained by Buyer on a non-confidential basis from a third party Entire Agreement: The estimate and these terms (together with any schedules or exhibits attached) constitute the entire agreement and understanding between the parties with respect to the subject matter hereof, and supersede any previous agreements or understandings, whether oral or written. By signing below, I confirm that I am authorized to bind the corporation. Memory Brown If you wish to decline this estimate, click on "Other Actions" in the top right corner and select "Decline" Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ Page 4 of 4|None|None|\n|Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ|Page 4 of 4||'],
#   ['identified as “confidential” in connection with this Agreement is confidential, solely for the use of performing\nthis Contract and may not be disclosed or copied unless authorized in advance by in writing. The\n\nparties shall be entitled to injunctive relief for any violation of this section. This section does not apply to\ninformation that is: (a) in the public domain; (b) known to Buyer at the time of disclosure; or (c) rightfully\nobtained by Buyer on a non-confidential basis from a third party\n\nEntire Agreement: The estimate and these terms (together with any schedules or exhibits attached)\nconstitute the entire agreement and understanding between the parties with respect to the subject matter\n\nhereof, and supersede any previous agreements or understandings, whether oral or written.\n\nBy signing below, | confirm that | am authorized to bind the corporation.\n\nJacgqule Ridley\nMemory Brown\n\nIf you wish to decline this estimate, click on "Other Actions" in the top right corner and select "Decline"\n\nDocument Ref: JZUWI-Y3UYJ-FAKTG-XBSBZ Page 4 of 4\n',
#    'identified as “confidential” in connection with this Agreement is confidential, solely for the use of performing \n',
#    'this Contract and may not be disclosed or copied unless authorized in advance by in writing. The \n',
#    'parties shall be entitled to injunctive relief for any violation of this section. This section does not apply to \n',
#    'information that is: (a) in the public domain; (b) known to Buyer at the time of disclosure; or (c) rightfully \n',
#    'obtained by Buyer on a non-confidential basis from a third party\n',
#    ' \n',
#    'Entire Agreement: The estimate and these terms (together with any schedules or exhibits attached) \n',
#    'constitute the entire agreement and understanding between the parties with respect to the subject matter \n',
#    'hereof, and supersede any previous agreements or understandings, whether oral or written.\n',
#    ' \n',
#    'By signing below, I confirm that I am authorized to bind the corporation.\n',
#    ' \n',
#    ' \n',
#    'Jacquit Ridley\n',
#    ' \n',
#    ' \n',
#    'Memory Brown\n',
#    'If you wish to decline this estimate, click on "Other Actions" in the top right corner and select "Decline"\n',
#    '|identified as “confidential” in connection with this Agreement is confidential, solely for the use of performing this Contract and may not be disclosed or copied unless authorized in advance by in writing. The parties shall be entitled to injunctive relief for any violation of this section. This section does not apply to information that is: (a) in the public domain; (b) known to Buyer at the time of disclosure; or (c) rightfully obtained by Buyer on a non-confidential basis from a third party Entire Agreement: The estimate and these terms (together with any schedules or exhibits attached) constitute the entire agreement and understanding between the parties with respect to the subject matter hereof, and supersede any previous agreements or understandings, whether oral or written. By signing below, I confirm that I am authorized to bind the corporation. Memory Brown If you wish to decline this estimate, click on "Other Actions" in the top right corner and select "Decline" Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ Page 4 of 4|None|None|\n|Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ|Page 4 of 4||',
#    'Document Ref: J3UWI-Y3UYJ-FAKTG-XBSBZ\n',
#    'Page 4 of 4\n']],
#  'Page_4': [['image',
#    'Signature Certificate\n',
#    'Reference number: J3UWI-Y3UYJ-FAKTG-XBSBZ\n',
#    'Signer\n',
#    'Timestamp\n',
#    'Signature\n',
#    'image',
#    'Memory Brown\nEmail: mbrown@tricorp.ca\n',
#    'Sent:\nViewed:\nSigned:\n',
#    '28 Mar 2022 21:11:40 UTC\n28 Mar 2022 22:05:31 UTC\n28 Mar 2022 22:07:48 UTC\n',
#    'IP address: 209.145.97.65 \nLocation: Prince Rupert, Canada\n',
#    'Document completed by all parties on:\n',
#    '28 Mar 2022 22:07:48 UTC\n',
#    'Page 1 of 1\n',
#    'Signed with PandaDoc\n',
#    'PandaDoc is a document workflow and certified eSignature\nsolution trusted by 30,000+ companies worldwide.\n'],
#   ['image',
#    [19.97820976597461, 'Arial-BoldMT'],
#    [7.988286275680707, 'ArialMT'],
#    ['Arial-BoldMT', 7.988286275680707],
#    ['Arial-BoldMT', 7.988286275680707],
#    ['Arial-BoldMT', 7.988286275680707],
#    'image',
#    ['Arial-BoldMT',
#     6.991623972945263,
#     7.988286275680707,
#     9.989104808050229,
#     'ArialMT'],
#    [6.991623972945263, 'ArialMT'],
#    [6.991623972945263, 'ArialMT'],
#    [6.991623972945263, 'ArialMT'],
#    [7.988286275680707, 'ArialMT'],
#    [7.988286275680707, 'ArialMT'],
#    [7.988286275680707, 'ArialMT'],
#    ['Arial-BoldMT', 7.988286275680679],
#    [7.988286275680679, 'ArialMT']],
#   ['Signature Certificate\n\nReference number: JSUWI-Y3UYJ-FAKTG-XBSBZ\n\nSigner Timestamp Signature\n\nMemory Brown\n\nEmail: mbrown@tricorp.ca Ja qu le R Wh ,\n\nSent: 28 Mar 2022 21:11:40 UTC\nViewed: 28 Mar 2022 22:05:31 UTC\nSigned: 28 Mar 2022 22:07:48 UTC\n\nIP address: 209.145.97.65\nLocation: Prince Rupert, Canada\n\nDocument completed by-all parties-on:\n28 Mar 2022 22:07:48 UTC\n\nPage 1 of 1\n\nSigned with PandaDoc\n\nPandaDoc is a document workflow and certified eSignature\nsolution trusted by 30,000+ companies worldwide.\n\n',
#    'Jacquie Ridley\n'],
#   [],
#   ['Signature Certificate\n\nReference number: JSUWI-Y3UYJ-FAKTG-XBSBZ\n\nSigner Timestamp Signature\n\nMemory Brown\n\nEmail: mbrown@tricorp.ca Ja qu le R Wh ,\n\nSent: 28 Mar 2022 21:11:40 UTC\nViewed: 28 Mar 2022 22:05:31 UTC\nSigned: 28 Mar 2022 22:07:48 UTC\n\nIP address: 209.145.97.65\nLocation: Prince Rupert, Canada\n\nDocument completed by-all parties-on:\n28 Mar 2022 22:07:48 UTC\n\nPage 1 of 1\n\nSigned with PandaDoc\n\nPandaDoc is a document workflow and certified eSignature\nsolution trusted by 30,000+ companies worldwide.\n\n',
#    'Signature Certificate\n',
#    'Reference number: J3UWI-Y3UYJ-FAKTG-XBSBZ\n',
#    'Signer\n',
#    'Timestamp\n',
#    'Signature\n',
#    'Jacquie Ridley\n',
#    'Memory Brown\nEmail: mbrown@tricorp.ca\n',
#    'Sent:\nViewed:\nSigned:\n',
#    '28 Mar 2022 21:11:40 UTC\n28 Mar 2022 22:05:31 UTC\n28 Mar 2022 22:07:48 UTC\n',
#    'IP address: 209.145.97.65 \nLocation: Prince Rupert, Canada\n',
#    'Document completed by all parties on:\n',
#    '28 Mar 2022 22:07:48 UTC\n',
#    'Page 1 of 1\n',
#    'Signed with PandaDoc\n',
#    'PandaDoc is a document workflow and certified eSignature\nsolution trusted by 30,000+ companies worldwide.\n']]}
