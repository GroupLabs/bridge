# %%
import storage as s

# %%
storage = s.Storage()

# %%
traversal = storage.graph.node_traversal("games" , "players", 3)

# %%
print(traversal)
# Out:
# {'path0': ['games.gameID = teamstats.gameID', 'teamstats.gameID = appearances.gameID', 'appearances.playerID = players.playerID'], 'path1': ['games.gameID = teamstats.gameID', 'teamstats.gameID = appearances.gameID', 'appearances.playerID = players.playerID'], 'path2': ['games.gameID = shots.gameID', 'shots.gameID = appearances.gameID', 'appearances.playerID = players.playerID'], 'path3': ['games.gameID = shots.gameID', 'shots.gameID = appearances.gameID', 'appearances.playerID = players.playerID'], 'path4': ['games.leagueID = leagues.leagueID', 'leagues.leagueID = appearances.leagueID', 'appearances.playerID = players.playerID'], 'path5': ['games.leagueID = leagues.leagueID', 'leagues.leagueID = appearances.leagueID', 'appearances.playerID = players.playerID'], 'path6': ['games.leagueID = appearances.leagueID', 'appearances.playerID = players.playerID'], 'path7': ['games.leagueID = appearances.leagueID', 'appearances.playerID = players.playerID'], 'path8': ['games.gameID = appearances.gameID', 'appearances.playerID = players.playerID'], 'path9': ['games.gameID = appearances.gameID', 'appearances.playerID = players.playerID']}

# %%
storage.graph.node_traversal("games" , "players", 5)

# %%
traversal[0]

# %%
print(storage.graph.node_traversal("games" , "players", 3)[0])

# %%
path_ways = {}
for index, record in enumerate(traversal):
    relationships = []
    for relationship in record[0]:
        join = relationship.get("key")
        relationships.append(join)
        print(join)
    path_ways[f"path{index}"] = relationships

print(path_ways)

# %%
print(path_ways)
path_ways.get("path0")
