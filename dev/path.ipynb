# %%
from pathlib import Path

string_path = 'Desktop/Mistral 7B Paper.pdf'
a = Path('/Users/noelthomas/Desktop/Mistral 7B Paper.pdf')

# %%
a.absolute().as_posix()
# Out:
# '/Users/noelthomas/Desktop/Mistral 7B Paper.pdf'

# %%
from unstructured.partition.pdf import partition_pdf

partition_pdf(string_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 from unstructured.partition.pdf import partition_pdf
# ----> 3 partition_pdf(string_path)
#
# File ~/Documents/GitHub/Bridge/.venv/lib/python3.11/site-packages/unstructured/documents/elements.py:526, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     524 @functools.wraps(func)
#     525 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 526     elements = func(*args, **kwargs)
#     527     sig = inspect.signature(func)
#     528     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/Documents/GitHub/Bridge/.venv/lib/python3.11/site-packages/unstructured/file_utils/filetype.py:627, in add_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     625 @functools.wraps(func)
# ...
